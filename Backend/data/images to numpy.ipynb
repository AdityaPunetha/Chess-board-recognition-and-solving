# %% [markdown]
# In this notebook, we'll convert our images into a numpy array dataset which can be read by our model for training.

# %% [markdown]
# # Import Dependencies

# %%
import numpy as np
import cv2
import os
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Creating Path

# %%
path = 'images/Labelled imgs/Chess Predictor.v10i.folder/train'

# %%
Pieces = ['Black King', 'Black Queen', 'Black Bishop', 'Black Knight', 'Black Rook', 'Black Pawn', 'White King', 'White Queen', 'White Bishop', 'White Knight', 'White Rook', 'White Pawn','Blank']

# %%
path+'/'+Pieces[0]+'/*.png'
# Out:
# 'images/Labelled imgs/Chess Predictor.v10i.folder/train/Black King/*.png'

# %% [markdown]
# ---

# %% [markdown]
# #### Taking image from each folder and pushing it into a list along with its forlder name

# %%
data = []

# %%
for index in range(len(Pieces)):
    for piece in glob(path+'/'+Pieces[index]+'/*.jpg'):
        data.append([cv2.imread(piece, cv2.IMREAD_GRAYSCALE),Pieces[index]])

# %%
data = np.array(data)
# Out:
# C:\Users\Rajeev\AppData\Local\Temp/ipykernel_8368/4012140830.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data = np.array(data)

# %%
data.shape
# Out:
# (92, 2)

# %%
plt.imshow(data[0][0], cmap='gray')
plt.title(data[0][1])
# Out:
# Text(0.5, 1.0, 'Black King')

# %% [markdown]
# # Saving the array

# %%
np.save('numpy arrays/V10_100x100_Grayscale.npy', data, allow_pickle=True)
